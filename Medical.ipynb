# %% [markdown]
# <a href="https://colab.research.google.com/github/Iqbalnm786/EDA/blob/main/Medical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA ON TRAINING DATA**
#
# ---

# %%
import pandas as pd
import numpy as np
df =pd.read_csv('/content/Train-1617360447408-1660719685476.csv')
train=df.copy()
train
# Out:
#        index  encounter_id  patient_id             race  gender      age  \
# 0      69375     197029140    51521940         Hispanic    Male  [80-90)
# 1      57272     163571946    92631357        Caucasian    Male  [60-70)
# 2      82347     256497366    30023982        Caucasian  Female  [50-60)
# 3      89608     289891212    93606021  AfricanAmerican  Female  [70-80)
# 4      24091      81873900    23464296        Caucasian    Male  [70-80)
# ...      ...           ...         ...              ...     ...      ...
# 66582  39934     124202466    23450508        Caucasian  Female  [70-80)
# 66583  47366     145667070    29324601        Caucasian    Male  [80-90)
# 66584  76555     231061116     2179062        Caucasian  Female  [60-70)
# 66585  25392      84911682    20531754                ?  Female  [80-90)
# 66586  51312     153167502    81985473        Caucasian  Female  [80-90)
#
#       weight  time_in_hospital medical_specialty  num_lab_procedures  ...  \
# ...

# %%
(df['race']=='?').sum()
# Out:
# np.int64(1504)

# %%
train.drop(['encounter_id','patient_id','weight'],axis=1,inplace=True)

# %%
train
# Out:
#        index             race  gender      age  time_in_hospital  \
# 0      69375         Hispanic    Male  [80-90)                 4
# 1      57272        Caucasian    Male  [60-70)                 3
# 2      82347        Caucasian  Female  [50-60)                 6
# 3      89608  AfricanAmerican  Female  [70-80)                 5
# 4      24091        Caucasian    Male  [70-80)                 9
# ...      ...              ...     ...      ...               ...
# 66582  39934        Caucasian  Female  [70-80)                11
# 66583  47366        Caucasian    Male  [80-90)                 4
# 66584  76555        Caucasian  Female  [60-70)                 2
# 66585  25392                ?  Female  [80-90)                 4
# 66586  51312        Caucasian  Female  [80-90)                 2
#
#       medical_specialty  num_lab_procedures  num_procedures  num_medications  \
# 0      Emergency/Trauma                  39               1                9
# ...

# %%
train['race']=train['race'].replace('?','unknown')

# %%
train['race'].value_counts()
# Out:
# race
# Caucasian          49906
# AfricanAmerican    12406
# unknown             1504
# Hispanic            1313
# Other               1050
# Asian                408
# Name: count, dtype: int64

# %%
train['medical_specialty']=train['medical_specialty'].replace('?','unknown')

# %%
train
# Out:
#        index             race  gender      age  time_in_hospital  \
# 0      69375         Hispanic    Male  [80-90)                 4
# 1      57272        Caucasian    Male  [60-70)                 3
# 2      82347        Caucasian  Female  [50-60)                 6
# 3      89608  AfricanAmerican  Female  [70-80)                 5
# 4      24091        Caucasian    Male  [70-80)                 9
# ...      ...              ...     ...      ...               ...
# 66582  39934        Caucasian  Female  [70-80)                11
# 66583  47366        Caucasian    Male  [80-90)                 4
# 66584  76555        Caucasian  Female  [60-70)                 2
# 66585  25392          unknown  Female  [80-90)                 4
# 66586  51312        Caucasian  Female  [80-90)                 2
#
#       medical_specialty  num_lab_procedures  num_procedures  num_medications  \
# 0      Emergency/Trauma                  39               1                9
# ...

# %%
train["race"] = (train["race"].replace("unknown", np.nan).fillna(train["race"].mode()[0]))

# %%
train
# Out:
#        index             race  gender      age  time_in_hospital  \
# 0      69375         Hispanic    Male  [80-90)                 4
# 1      57272        Caucasian    Male  [60-70)                 3
# 2      82347        Caucasian  Female  [50-60)                 6
# 3      89608  AfricanAmerican  Female  [70-80)                 5
# 4      24091        Caucasian    Male  [70-80)                 9
# ...      ...              ...     ...      ...               ...
# 66582  39934        Caucasian  Female  [70-80)                11
# 66583  47366        Caucasian    Male  [80-90)                 4
# 66584  76555        Caucasian  Female  [60-70)                 2
# 66585  25392        Caucasian  Female  [80-90)                 4
# 66586  51312        Caucasian  Female  [80-90)                 2
#
#       medical_specialty  num_lab_procedures  num_procedures  num_medications  \
# 0      Emergency/Trauma                  39               1                9
# ...

# %%
train['medical_specialty']=train['medical_specialty'].replace("unknown",np.nan)
train['medical_specialty'].fillna(train['medical_specialty'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-687052486.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['medical_specialty'].fillna(train['medical_specialty'].mode()[0],inplace=True)

# %%
train
# Out:
#        index             race  gender      age  time_in_hospital  \
# 0      69375         Hispanic    Male  [80-90)                 4
# 1      57272        Caucasian    Male  [60-70)                 3
# 2      82347        Caucasian  Female  [50-60)                 6
# 3      89608  AfricanAmerican  Female  [70-80)                 5
# 4      24091        Caucasian    Male  [70-80)                 9
# ...      ...              ...     ...      ...               ...
# 66582  39934        Caucasian  Female  [70-80)                11
# 66583  47366        Caucasian    Male  [80-90)                 4
# 66584  76555        Caucasian  Female  [60-70)                 2
# 66585  25392        Caucasian  Female  [80-90)                 4
# 66586  51312        Caucasian  Female  [80-90)                 2
#
#       medical_specialty  num_lab_procedures  num_procedures  num_medications  \
# 0      Emergency/Trauma                  39               1                9
# ...

# %%
(train['number_outpatient']=='?').sum()
# Out:
# np.int64(0)

# %%
train["diag_1"] = train["diag_1"].replace("?", np.nan)
train['diag_1'].fillna(train['diag_1'].mode()[0],inplace=True)
train["diag_1"] = pd.to_numeric(train["diag_1"], errors="coerce")
train = train.dropna(subset=["diag_1"])
# Out:
# /tmp/ipython-input-220806858.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['diag_1'].fillna(train['diag_1'].mode()[0],inplace=True)

# %%
train["diag_2"] = train["diag_2"].replace("?", np.nan)
train['diag_2'].fillna(train['diag_2'].mode()[0],inplace=True)
train["diag_2"] = pd.to_numeric(train["diag_2"], errors="coerce")
train = train.dropna(subset=["diag_2"])
# Out:
# /tmp/ipython-input-1895602224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["diag_2"] = train["diag_2"].replace("?", np.nan)
# /tmp/ipython-input-1895602224.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
train["diag_3"] = train["diag_3"].replace("?", np.nan)
train['diag_3'].fillna(train['diag_3'].mode()[0],inplace=True)
train["diag_3"] = pd.to_numeric(train["diag_3"], errors="coerce")
train = train.dropna(subset=["diag_3"])
# Out:
# /tmp/ipython-input-3586835937.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['diag_3'].fillna(train['diag_3'].mode()[0],inplace=True)

# %%
train['diag_3'].head(20)
# Out:
# 0     585.0
# 1     569.0
# 2     585.0
# 3     250.0
# 4     300.0
# 5     414.0
# 6     998.0
# 7     780.0
# 8     458.0
# 9     427.0
# 10    276.0
# 11    585.0
# 12    625.0
# 13    250.0
# 14    518.0
# 15    585.0
# 16    496.0
# 17    255.0
# 18    276.0
# 19    250.0
# Name: diag_3, dtype: float64

# %%
train.drop(['diag_4','X1','X2','race'],axis=1,inplace=True)

# %%
train['diag_5'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 61107 entries, 0 to 66586
# Series name: diag_5
# Non-Null Count  Dtype
# --------------  -----
# 61107 non-null  float64
# dtypes: float64(1)
# memory usage: 954.8 KB

# %%
train.columns
# Out:
# Index(['index', 'gender', 'age', 'time_in_hospital', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'diag_5', 'number_diagnoses', 'X3', 'X4', 'X5',
#        'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16',
#        'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'change',
#        'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
train['change'].isnull().sum()
# Out:
# np.int64(0)

# %%
train.columns
# Out:
# Index(['index', 'gender', 'age', 'time_in_hospital', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'diag_5', 'number_diagnoses', 'X3', 'X4', 'X5',
#        'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16',
#        'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'change',
#        'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
train.to_csv('dataset.csv',index=False)

# %% [markdown]
# # **EDA ON TESTING DATA**
#
# ---

# %%
df1 =pd.read_csv('/content/test-1617360461595-1660719701431.csv')
test=df1.copy()
test
# Out:
#        index  encounter_id  patient_id             race  gender      age  \
# 0      11128      46325466     3928383        Caucasian  Female  [70-80)
# 1      79758     245219616    60926103        Caucasian    Male  [60-70)
# 2      52497     155321232    25234848  AfricanAmerican    Male  [70-80)
# 3      64504     179491944    86935374        Caucasian  Female  [70-80)
# 4        987       7425954     2486826  AfricanAmerican  Female  [50-60)
# ...      ...           ...         ...              ...     ...      ...
# 16642  69643     198316824    71780013        Caucasian    Male  [70-80)
# 16643  29787      96993108    23318685        Caucasian    Male  [70-80)
# 16644  44710     137896878    90856791        Caucasian  Female  [50-60)
# 16645  28486      93395658     3233259                ?    Male  [70-80)
# 16646  39179     121984746    41817384        Caucasian  Female  [80-90)
#
#       weight  time_in_hospital       medical_specialty  num_lab_procedures  \
# ...

# %%
test.drop(['encounter_id','patient_id','weight'],axis=1,inplace=True)

# %%
train = train[train["gender"] != "Unknown/Invalid"]

# %%
test['race']=test['race'].replace('?','unknown')

# %%
test['medical_specialty']=test['medical_specialty'].replace('?','unknown')

# %%
test["race"] = (test["race"].replace("unknown", np.nan).fillna(test["race"].mode()[0]))

# %%
test['medical_specialty']=test['medical_specialty'].replace("unknown",np.nan)
test['medical_specialty'].fillna(test['medical_specialty'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-3345553838.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['medical_specialty'].fillna(test['medical_specialty'].mode()[0],inplace=True)

# %%
test["diag_1"] = test["diag_1"].replace("?", np.nan)
test['diag_1'].fillna(test['diag_1'].mode()[0],inplace=True)
test["diag_1"] = pd.to_numeric(test["diag_1"], errors="coerce")
test= test.dropna(subset=["diag_1"])
# Out:
# /tmp/ipython-input-2665334394.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['diag_1'].fillna(test['diag_1'].mode()[0],inplace=True)

# %%
test["diag_2"] = test["diag_2"].replace("?", np.nan)
test['diag_2'].fillna(test['diag_2'].mode()[0],inplace=True)
test["diag_2"] = pd.to_numeric(test["diag_2"], errors="coerce")
test= test.dropna(subset=["diag_2"])
# Out:
# /tmp/ipython-input-1208546653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["diag_2"] = test["diag_2"].replace("?", np.nan)
# /tmp/ipython-input-1208546653.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
test["diag_3"] = test["diag_3"].replace("?", np.nan)
test['diag_3'].fillna(test['diag_1'].mode()[0],inplace=True)
test["diag_3"] = pd.to_numeric(test["diag_3"], errors="coerce")
test= test.dropna(subset=["diag_3"])
# Out:
# /tmp/ipython-input-310465851.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['diag_3'].fillna(test['diag_1'].mode()[0],inplace=True)

# %%
test['diag_4']
# Out:
# 0          410
# 1          401
# 2          599
# 3          276
# 4        250.6
#          ...
# 16642      707
# 16643      250
# 16644      276
# 16645      600
# 16646      401
# Name: diag_4, Length: 15314, dtype: object

# %%
test.drop(['diag_4','X1','X2'],axis=1,inplace=True)

# %%
test.columns
# Out:
# Index(['index', 'race', 'gender', 'age', 'time_in_hospital',
#        'medical_specialty', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'diag_5',
#        'number_diagnoses', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20',
#        'X21', 'X22', 'X23', 'X24', 'X25', 'change', 'diabetesMed'],
#       dtype='object')

# %%
test = test[test["gender"] != "Unknown/Invalid"]

# %%
test.to_csv('test.csv',index=False)

# %%
train['diag_1'].describe()
# Out:
# count    61106.000000
# mean       489.490543
# std        202.906488
# min          3.000000
# 25%        410.000000
# 50%        436.000000
# 75%        590.000000
# max        999.000000
# Name: diag_1, dtype: float64

# %% [markdown]
# ### **MODEL BUILDING**
#
# ---

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB

# %%
x_train = train.drop(columns=["readmitted"])
y_train = train["readmitted"]

x_test=test.copy()

# %%
cat_cols = x_train.select_dtypes(include="object").columns
num_cols = x_train.select_dtypes(exclude="object").columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols)
    ]
)

# %%
models = {
    "Logistic Regression": LogisticRegression(
        max_iter=3000, solver="saga", class_weight="balanced", n_jobs=-1
    ),
    "KNN": KNeighborsClassifier(n_neighbors=5),  # keep for comparison
    "Decision Tree": DecisionTreeClassifier(
        max_depth=10, min_samples_leaf=50, class_weight="balanced"
    ),
    "Random Forest": RandomForestClassifier(
        n_estimators=100, max_depth=12, min_samples_leaf=50, n_jobs=-1
    ),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "SVM": LinearSVC(class_weight="balanced", max_iter=2000)

}

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score, accuracy_score

results = {}

for name, clf in models.items():
    pipe = Pipeline(steps=[
        ("preprocess", preprocessor),
        ("model", clf)
    ])

    pipe.fit(x_train, y_train)
    y_pred = pipe.predict(x_train)   # or validation set

    results[name] = {
        "Accuracy": accuracy_score(y_train, y_pred),
        "F1 Score": f1_score(y_train, y_pred, average="weighted")
    }

results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                      Accuracy  F1 Score
# Logistic Regression  0.625716  0.624007
# KNN                  0.777207  0.776858
# Decision Tree        0.651082  0.651574
# Random Forest        0.648463  0.637396
# Gradient Boosting    0.646254  0.639783
# SVM                  0.624832  0.623196

# %%
best_model_name = results_df["F1 Score"].idxmax()
print("Best Model:" ,best_model_name )
# Out:
# Best Model: KNN

# %%
best_model = models[best_model_name]
final_pipe = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", best_model)
])

final_pipe.fit(x_train, y_train)
y_pred = final_pipe.predict(x_test)

# %%
test["predicted_readmitted"] = final_pipe.predict(x_test)

# %%
test[["predicted_readmitted"]].to_csv("submission.csv", index=False)

# %%
dftest=pd.read_csv('/content/submission.csv')
dfpredict=pd.read_csv('/content/test.csv')

combined=pd.concat([dfpredict,dftest],axis=1)
combined.to_csv('combined.csv',index=False)
